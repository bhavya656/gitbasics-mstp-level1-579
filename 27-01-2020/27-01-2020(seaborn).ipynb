# %%
import seaborn as sb

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.random.rand(20)
y=np.random.rand(20)
plt.plot(x,y,"ko",alpha=0.1,linewidth=2,markersize=20)

# %%
sb.set()
plt.plot(x,y)

# %%
import pandas as pd
data=pd.DataFrame({'x':[2,3,5,6],'y':[4,3,88,99]})
data
# Out:
#    x   y
# 0  2   4
# 1  3   3
# 2  5  88
# 3  6  99

# %%
data['x']
# Out:
# 0    2
# 1    3
# 2    5
# 3    6
# Name: x, dtype: int64

# %%
data['y']
# Out:
# 0     4
# 1     3
# 2    88
# 3    99
# Name: y, dtype: int64

# %%
plt.plot(data['x'],data['y'],'rs')

# %% [markdown]
# ## Relational plot :high level functioning plot
# ### scatter
# ### line

# %%
sb.set()
sb.relplot(x='x',y='y',data=data)

# %%
sb.relplot(x='x',y='y',data=data,hue="y")

# %% [markdown]
# ### Loading a datasets

# %%
sb.get_dataset_names()
# Out:
# C:\Users\kvsw\Anaconda3\lib\site-packages\seaborn\utils.py:376: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 376 of the file C:\Users\kvsw\Anaconda3\lib\site-packages\seaborn\utils.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   gh_list = BeautifulSoup(http)
# ['anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'iris',
#  'mpg',
#  'planets',
#  'tips',
#  'titanic']

# %%
sb.set(style="darkgrid")
t=sb.load_dataset("tips")
t.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sb.relplot(x="total_bill",y="day",data=t)

# %%
sb.relplot(x="total_bill",y="day",data=t,hue="tip")

# %%
sb.relplot(x="total_bill",y="size",data=t,hue="tip",kind="line")

# %%
import seaborn as sb
sb.set(style="darkgrid")
i=sb.load_dataset("iris")
i.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
import seaborn as sb
sb.relplot(x="sepal_length",y="species",data=i,hue="sepal_width")

# %%
sb.relplot(x="sepal_width",y="petal_width",data=i,hue="species",col="species")

# %%
sb.relplot(x="sepal_width",y="petal_width",data=i,hue="species",col="species",kind="line")

# %% [markdown]
# ### linear regression model plot

# %%
sb.lmplot("total_bill","tip",hue="smoker",data=t,col="time")

# %% [markdown]
# ### Categorical data plot
# ### catplot:swarm plot,scatterplot,barplot,violinplot

# %%
sb.catplot(x="species",y="petal_length",data=i)

# %%
sb.catplot(x="species",y="petal_length",hue="sepal_width",data=i)

# %%
sb.catplot(x="species",y="petal_length",hue="sepal_width",data=i,kind="swarm")

# %%
sb.catplot(x="species",y="petal_length",data=i,kind="violin")

# %%
sb.catplot(x="species",y="petal_length",data=i,kind="bar")

# %% [markdown]
# ### Boxplot

# %%
f,axs=plt.subplots(1,2)
sb.boxplot(x="species",y="sepal_length",data=i,ax=axs[0])
sb.scatterplot(x="species",y="sepal_length",hue="petal_length",data=i,ax=axs[1])

# %%
sb.boxplot(x="total_bill",y="day",data=t)

# %%
sb.swarmplot(x="total_bill",y="day",data=t)

# %% [markdown]
# #### Visualization of data sets in plots
# #### jointplot,kde-kernaldensity,hex,scatter,reg,resid

# %%
help(sb.jointplot)
# Out:
# Help on function jointplot in module seaborn.axisgrid:
#
# jointplot(x, y, data=None, kind='scatter', stat_func=None, color=None, height=6, ratio=5, space=0.2, dropna=True, xlim=None, ylim=None, joint_kws=None, marginal_kws=None, annot_kws=None, **kwargs)
#     Draw a plot of two variables with bivariate and univariate graphs.
#
#     This function provides a convenient interface to the :class:`JointGrid`
#     class, with several canned plot kinds. This is intended to be a fairly
#     lightweight wrapper; if you need more flexibility, you should use
#     :class:`JointGrid` directly.
#
#     Parameters
#     ----------
#     x, y : strings or vectors
#         Data or names of variables in ``data``.
#     data : DataFrame, optional
#         DataFrame when ``x`` and ``y`` are variable names.
#     kind : { "scatter" | "reg" | "resid" | "kde" | "hex" }, optional
#         Kind of plot to draw.
#     stat_func : callable or None, optional
#         *Deprecated*
# ...

# %%
sb.jointplot(x="total_bill",y="tip",data=t)

# %%
sb.jointplot(x="total_bill",y="tip",data=t,kind="kde",hue="smoker")
# Out:
# C:\Users\kvsw\Anaconda3\lib\site-packages\seaborn\distributions.py:423: UserWarning: The following kwargs were not used by contour: 'hue'
#   cset = contour_func(xx, yy, z, n_levels, **kwargs)

# %%
sb.jointplot(x="total_bill",y="tip",data=t,kind="hex")

# %%
sb.jointplot(x="total_bill",y="tip",data=t,kind="reg",color='k',height=3.5,ratio=5)

# %% [markdown]
# ### Pairplot

# %%
sb.pairplot(data=i)

# %%
sb.pairplot(data=i,hue="species",palette='muted')

# %%
sb.pairplot(data=i,hue="species",markers=["o","s","D"])

# %%
sb.pairplot(i,vars=["sepal_width","sepal_length","petal_width","petal_length"])

# %%
sb.pairplot(i,diag_kind="kde")

# %%
sb.pairplot(i,diag_kind="kde",markers="+")

# %% [markdown]
# ### Distributeplot

# %%
x=np.random.rand(50)
sb.distplot(x)

# %% [markdown]
# ### Facetgrid plot

# %%
ff=sb.FacetGrid(i,col="species")
ff.map(plt.hist,"petal_length")

# %%
ff=sb.FacetGrid(t,col="size")
ff.map(plt.hist,"tip")

# %% [markdown]
# ### pairgrid

# %%
sb.set(style="ticks")
pp=sb.pairGrid(i)
pp.map(plt.Scatter)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-88-3ae164fa686d> in <module>
#       1 sb.set(style="ticks")
# ----> 2 pp=sb.pairGrid(i)
#       3 pp.map(plt.Scatter)
#
# AttributeError: module 'seaborn' has no attribute 'pairGrid'
